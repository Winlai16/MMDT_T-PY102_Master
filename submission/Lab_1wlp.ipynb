# %% [markdown]
# <a href="https://colab.research.google.com/github/Winlai16/MMDT_T-PY102_Master/blob/main/submission/Lab_1wlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def submission_check():
    """
    Return your student ID as a string.

    Example:
    "PY102001001"
    """
    return "REPLACE_WITH_YOUR_STUDENT_ID"
